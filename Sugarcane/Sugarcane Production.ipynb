# %% [markdown]
# # Sugarcane Production Data Analysis

# %% [markdown]
# ### 1. Importing the Libraries
# <ul>
#
# <li>PANDAS to work with dataset</li>
# <li>SEABORN to understand the data</li>
# <li>MATPLOTLIB to visualise the data</li>
#
# </ul>

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### 2. Loading the Dataset

# %%
df = pd.read_csv('D:/data cleaning/datasets/Sugarcane/List of Countries by Sugarcane Production.csv')
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# 2                        88287         1.675.215             73.459,1
# 3                    1.264,303         1.336.575             65.442,2
# 4                       324219         1.130.820               57.879
# ..                         ...               ...                  ...
# 98                          16                 3             28.386,4
# 99                          51               NaN                  NaN
# 100                          9                 2                   25
# 101                          6                 1             11.949,8
# 102                          0                 0             83.034,2
#
# [103 rows x 7 columns]

# %% [markdown]
# ### 3. Data Cleaning
# #### Realised some requirement for changes in the dataset
#
# <ol>
#
# <li>Presence of useless spaces in the names of the columns</li>
# <li>Presence of '.' and ',' both in many integer values</li>
#
#
# </ol>

# %%
df['Production (Tons)'] = df['Production (Tons)'].str.replace(".","")
df['Acreage (Hectare)'] = df['Acreage (Hectare)'].str.replace(".","")
df['Production per Person (Kg)'] = df['Production per Person (Kg)'].str.replace(".","")
df['Production per Person (Kg)'] = df['Production per Person (Kg)'].str.replace(",",".")
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].str.replace(".","")
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].str.replace(",",".")


df.rename(columns= {'Production (Tons)':'Production(Tons)'}, inplace=True)
df.rename(columns= {'Acreage (Hectare)':'Acreage(Hectare)'},inplace=True)
df.rename(columns= {'Production per Person (Kg)':'Production per Person(Kg)'},inplace=True)
df.rename(columns= {'Yield (Kg / Hectare)':'Yield(Kg/Hectare)'},inplace=True)
df
# Out:
#      Unnamed: 0    Country      Continent Production(Tons)  \
# 0             0     Brazil  South America        768678382
# 1             1      India           Asia        348448000
# 2             2      China           Asia        123059739
# 3             3   Thailand           Asia         87468496
# 4             4   Pakistan           Asia         65450704
# ..          ...        ...            ...              ...
# 98           98    Lebanon           Asia               97
# 99           99   Djibouti         Africa               53
# 100         100  Singapore           Asia               50
# 101         101      Samoa        Oceania               12
# 102         102      Syria           Asia                1
#
#     Production per Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                    3668.531         10226205           75167.5
# 1                      260721          4950000           70393.5
# 2                       88287          1675215           73459.1
# 3                    1264.303          1336575           65442.2
# 4                      324219          1130820             57879
# ..                        ...              ...               ...
# 98                         16                3           28386.4
# 99                         51              NaN               NaN
# 100                         9                2                25
# 101                         6                1           11949.8
# 102                         0                0           83034.2
#
# [103 rows x 7 columns]

# %% [markdown]
# #### Finding and droping the NULL values

# %%
df = df.dropna().reset_index()
df
# Out:
#      index  Unnamed: 0    Country      Continent Production(Tons)  \
# 0        0           0     Brazil  South America        768678382
# 1        1           1      India           Asia        348448000
# 2        2           2      China           Asia        123059739
# 3        3           3   Thailand           Asia         87468496
# 4        4           4   Pakistan           Asia         65450704
# ..     ...         ...        ...            ...              ...
# 97      97          97      Spain         Europe              394
# 98      98          98    Lebanon           Asia               97
# 99     100         100  Singapore           Asia               50
# 100    101         101      Samoa        Oceania               12
# 101    102         102      Syria           Asia                1
#
#     Production per Person(Kg) Acreage(Hectare) Yield(Kg/Hectare)
# 0                    3668.531         10226205           75167.5
# 1                      260721          4950000           70393.5
# 2                       88287          1675215           73459.1
# 3                    1264.303          1336575           65442.2
# 4                      324219          1130820             57879
# ..                        ...              ...               ...
# 97                          8                9           43596.5
# 98                         16                3           28386.4
# 99                          9                2                25
# 100                         6                1           11949.8
# 101                         0                0           83034.2
#
# [102 rows x 8 columns]

# %% [markdown]
# #### Deleting Unnecessary Columns

# %%
del df['index']
del df['Unnamed: 0']

# %% [markdown]
# #### Checking for the Datatypes of the Columns

# %%
df.dtypes
# Out:
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production per Person(Kg)    object
# Acreage(Hectare)             object
# Yield(Kg/Hectare)            object
# dtype: object

# %% [markdown]
# #### Fixing the datatypes of the Columns

# %%
df['Production(Tons)'] = df['Production(Tons)'].astype(float)
df['Production per Person(Kg)'] = df['Production per Person(Kg)'].astype(float)
df['Acreage(Hectare)'] = df['Acreage(Hectare)'].astype(float)
df['Yield(Kg/Hectare)'] = df['Yield(Kg/Hectare)'].astype(float)

# %% [markdown]
# ### 4.Data Analysis

# %% [markdown]
# #### How many countries produce sugarcane from each of the continent?

# %%
print(df['Continent'].value_counts())
df['Continent'].value_counts().plot(kind = 'bar')
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64
# <Axes: xlabel='Continent'>

# %% [markdown]
# ### 5. Generalised graphs

# %% [markdown]
# #### Graph of Yield per hectare of every country as compared to other countries from the same continent

# %%
plt.figure(figsize=(15, 30))  

# Africa
plt.subplot(6, 1, 1)
sns.barplot(y=df[df['Continent'] == 'Africa']['Yield(Kg/Hectare)'], x=df[df['Continent'] == 'Africa']['Country'])
plt.xticks(rotation=90)
plt.title("Africa")

# Asia
plt.subplot(6, 1, 2)
sns.barplot(y=df[df['Continent'] == 'Asia']['Yield(Kg/Hectare)'], x=df[df['Continent'] == 'Asia']['Country'])
plt.xticks(rotation=90)
plt.title("Asia")

# North America
plt.subplot(6, 1, 3)
sns.barplot(y=df[df['Continent'] == 'North America']['Yield(Kg/Hectare)'], x=df[df['Continent'] == 'North America']['Country'])
plt.xticks(rotation=90)
plt.title("North America")

# South America
plt.subplot(6, 1, 4)
sns.barplot(y=df[df['Continent'] == 'South America']['Yield(Kg/Hectare)'], x=df[df['Continent'] == 'South America']['Country'])
plt.xticks(rotation=90)
plt.title("South America")

# Oceania
plt.subplot(6, 1, 5)
sns.barplot(y=df[df['Continent'] == 'Oceania']['Yield(Kg/Hectare)'], x=df[df['Continent'] == 'Oceania']['Country'])
plt.xticks(rotation=90)
plt.title("Oceania")

# Europe
plt.subplot(6, 1, 6)
sns.barplot(y=df[df['Continent'] == 'Europe']['Yield(Kg/Hectare)'], x=df[df['Continent'] == 'Europe']['Country'])
plt.xticks(rotation=90)
plt.title("Europe")

plt.tight_layout()  
plt.show()

# %% [markdown]
# #### Graph of Yield vs Country

# %%
plt.figure(figsize = (15,30))
sns.boxplot(
    data= df,
    x=df['Yield(Kg/Hectare)'] , y=df['Country'],hue= df['Continent'],orient = 'y')

plt.show()

# %% [markdown]
# ### 6. Checking the outliers

# %%
plt.figure(figsize=(12, 12))

# Distribution of Production(Tons)
plt.subplot(2, 2, 1)
sns.histplot(df['Production(Tons)'], kde=True)
plt.title('Production (Tons) Distribution')

# Distribution of Production per Person(Kg)
plt.subplot(2, 2, 2)
sns.histplot(df['Production per Person(Kg)'], kde=True)
plt.title('Production per Person (Kg) Distribution')

# Distribution of Acreage(Hectare)
plt.subplot(2, 2, 3)
sns.histplot(df['Acreage(Hectare)'], kde=True)
plt.title('Acreage (Hectare) Distribution')

# Distribution of Yield(Kg/Hectare)
plt.subplot(2, 2, 4)
sns.histplot(df['Yield(Kg/Hectare)'], kde=True)
plt.title('Yield (Kg/Hectare) Distribution')

plt.tight_layout() 
plt.show()

# %% [markdown]
# As we can see that every column except for YIELD is skewing towards the right. From that we can say that the data in YIELD is the only data which is evenly spreadout.
#
# NOTE- In analysis process we can not remove the outliers because then the countries produiong the max amount of cane will also get removed. But we can see how many outliers we will have.
#
# Also note that YIELD will be the only column which will not be able to give the outliers because of its even spreading which we can check using a boxplot.

# %%
# boxplot for every column
# column wise distribution plot
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df['Production(Tons)'])
plt.subplot(2,2,2)
sns.boxplot(df['Production per Person(Kg)'])
plt.subplot(2,2,3)
sns.boxplot(df['Acreage(Hectare)'])
plt.subplot(2,2,4)
sns.boxplot(df['Yield(Kg/Hectare)'])
plt.show()

# %% [markdown]
# We can see from the df.describe that the difference in the values of 75% and max is very far in every colun except for the Yield(Kg/Hectare) column that is the reason why we are getting the outliers.
# <br>
# <br>
# Also see from the boxplot above that we get an outlier in every column but not in Yield column because of the same reason.

# %%
df.describe()
# Out:
#        Production(Tons)  Production per Person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# ### 7. Bivariate Data

# %% [markdown]
# #### Production percent<br>
# We are making a new dataset to plot the Country vs its contribution in producing the sugarcane in the world graph.

# %%
df_new = df[['Country','Production(Tons)']].set_index("Country")
df_new['production percent'] = (df_new['Production(Tons)'] / df_new['Production(Tons)'].sum())*100
df_new['production percent'].head(10).plot(kind = 'bar' , figsize=(10,6),   title = 'Production Percent per Country')
plt.show()

# %% [markdown]
# #### Making the same graph using sns.
# <br>
# <br>
# Also note that to get the names of the countries using pandas you can use the new df which we made as df_new because it will always show the index on the x axis.

# %%
df['production percent'] = df_new['production percent']
plt.figure(figsize=(10,10))
ax = sns.barplot(data = df_new.head(10), y = 'production percent',x = 'Country')
plt.xticks(rotation = 90)
plt.title("Production percent per country")
plt.show()

# %%
df_new['production percent'].plot(kind = 'pie',autopct = '%0.2f%%')
plt.show()

# %% [markdown]
# #### Which Country has the max land?

# %%
plt.figure(figsize=(10,10))
df_acr = df.sort_values("Acreage(Hectare)", ascending=False)

ax = sns.barplot(y = df_acr['Acreage(Hectare)'],x = df_acr['Country'].head(10))
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Which Country has the max yield per hectare?

# %%
plt.figure(figsize=(10,10))
df_yph = df.sort_values("Yield(Kg/Hectare)", ascending=False)

ax = sns.barplot(data = df_yph.head(10),y = 'Yield(Kg/Hectare)',x = 'Country')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Which country has the highest production?

# %%
plt.figure(figsize=(10,10))
df_p = df.sort_values("Production(Tons)", ascending=False)

ax = sns.barplot(data = df_p.head(10),y = 'Production(Tons)',x = 'Country')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(12, 12))

# Distribution of Production(Tons)
plt.subplot(2, 2, 1)
sns.histplot(df['Production(Tons)'], kde=True)
plt.title('Production (Tons) Distribution')

# Distribution of Production per Person(Kg)
plt.subplot(2, 2, 2)
sns.histplot(df['Production per Person(Kg)'], kde=True)
plt.title('Production per Person (Kg) Distribution')

# Distribution of Acreage(Hectare)
plt.subplot(2, 2, 3)
sns.histplot(df['Acreage(Hectare)'], kde=True)
plt.title('Acreage (Hectare) Distribution')

# Distribution of Yield(Kg/Hectare)
plt.subplot(2, 2, 4)
sns.histplot(df['Yield(Kg/Hectare)'], kde=True)
plt.title('Yield (Kg/Hectare) Distribution')

plt.tight_layout() 
plt.show()

# %% [markdown]
# ### 8. Correlation

# %% [markdown]
# We have made a new dataset without the 2 columns with country names and continent names so that we are able to find the correlation among the columns.

# %%
df_1 = df.drop(['Country','Continent'], axis =1)
df_1.corr()
# Out:
#                            Production(Tons)  Production per Person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production per Person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg/Hectare)                  0.132812                   0.017999
# production percent                      NaN                        NaN
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.997550           0.132812
# Production per Person(Kg)          0.012557           0.017999
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000
# production percent                      NaN                NaN
#
#                            production percent
# Production(Tons)                          NaN
# Production per Person(Kg)                 NaN
# Acreage(Hectare)                          NaN
# Yield(Kg/Hectare)                         NaN
# production percent                        NaN

# %%
sns.heatmap(df_1.corr(),annot=True,cmap = 'coolwarm')
plt.show()

# %% [markdown]
# #### Do countries with more area produce more sugarcane?<br>
# -YES<br>

# %%
# you can also use scatterplot for the same

sns.scatterplot(data = df, x = 'Production(Tons)', y = 'Acreage(Hectare)')
# Out:
# <Axes: xlabel='Production(Tons)', ylabel='Acreage(Hectare)'>

# %% [markdown]
# #### Do countries which yield more sugarcane per hectare produces more sugarcane in total?<br>
# -NO<br>

# %%
sns.scatterplot(data = df, x = 'Production(Tons)', y = 'Yield(Kg/Hectare)')
plt.show()

# %% [markdown]
# ### 9. Analysis by Continent

# %% [markdown]
# #### Segregating the data in a new dataframe on the basis of Continent

# %%
df_continent = df.groupby('Continent').sum()
df_continent = df_continent.drop(['Country'], axis = 1)
df_continent
# Out:
#                Production(Tons)  Production per Person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# South America       865588126.0                3505531.738        11369236.0
#
#                Yield(Kg/Hectare)  production percent
# Continent
# Africa                 2142107.5                 0.0
# Asia                   1171871.4                 0.0
# Europe                  131870.9                 0.0
# North America          1082602.4                 0.0
# Oceania                 162419.1                 0.0
# South America           677192.7                 0.0

# %% [markdown]
# #### Which continent produces maximum sugarcane?

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df_continent['Production(Tons)'].sort_values(ascending=False).plot(kind = 'bar')
plt.title("Continent wise production")
plt.show()

# %% [markdown]
# #### Which continent has the max Acreage?

# %%
df_continent['Acreage(Hectare)'].sort_values(ascending=False).plot(kind = 'bar')
plt.title("Continent wise Acreage")
plt.show()

# %% [markdown]
# #### Do number of countries producing sugarcane in a continent affect the production?<br>
# -NO

# %%
df_continent['Nos_of_countries'] = df.groupby("Continent").count()["Country"]

continent_names = df_continent.index.tolist()
sns.lineplot(data = df_continent, y = 'Production(Tons)', x = 'Nos_of_countries')
plt.xticks(df_continent['Nos_of_countries'], continent_names,rotation = 90)
plt.title("No of Countries vs production")
plt.show()

# %% [markdown]
# Do continent with highest land produces more sugarcane?<br>-YES

# %%
df_continent['Acreage_continent'] = df.groupby("Continent")["Acreage(Hectare)"].sum()

continent_names = df_continent.index.tolist()
sns.lineplot(data = df_continent, y = 'Production(Tons)', x = 'Acreage(Hectare)')
plt.xticks(df_continent['Acreage_continent'], continent_names,rotation = 90)
plt.title("Continent wise Acreage vs production")
plt.show()

# %% [markdown]
# #### Production distribution by continent

# %%
df_continent['Production(Tons)'].plot(kind = 'pie',autopct = '%0.2f%%')
plt.title("Production distribution by continent")
plt.show()

# %% [markdown]
# ### 10. Correlation for continent

# %%
df_continent.corr()
# Out:
#                            Production(Tons)  Production per Person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production per Person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
# production percent                      NaN                        NaN
# Nos_of_countries                   0.109244                   0.540086
# Acreage_continent                  0.994897                   0.463215
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.994897           0.091201
# Production per Person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000
# production percent                      NaN                NaN
# Nos_of_countries                   0.132817           0.989712
# Acreage_continent                  1.000000           0.111166
#
#                            production percent  Nos_of_countries  \
# Production(Tons)                          NaN          0.109244
# Production per Person(Kg)                 NaN          0.540086
# Acreage(Hectare)                          NaN          0.132817
# Yield(Kg/Hectare)                         NaN          0.989712
# production percent                        NaN               NaN
# Nos_of_countries                          NaN          1.000000
# Acreage_continent                         NaN          0.132817
#
#                            Acreage_continent
# Production(Tons)                    0.994897
# Production per Person(Kg)           0.463215
# Acreage(Hectare)                    1.000000
# Yield(Kg/Hectare)                   0.111166
# production percent                       NaN
# Nos_of_countries                    0.132817
# Acreage_continent                   1.000000

# %%
sns.heatmap(df_continent.corr(), annot=True,cmap = 'coolwarm' )
plt.show()
